# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import time

# %%
df=pd.read_csv("G:/cadd/Excel File/Salary.csv")
#("File location/file name")

# %%
#Print top 10 data
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4                 NaN            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %% [markdown]
# # Data Management

# %%
#1 : How many rows are there?
#2 : Which all columns are importants for valuebale data?
#3 : Unnecessary columns need to delete

# %%
#1 How many null values are present in given data

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             1
# JobTitle                 0
# BasePay                606
# OvertimePay              0
# OtherPay                 2
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
#2 : Print the numnber of rows and columns

# %%
df.shape
# Out:
# (148654, 13)

# %%
#1 : How much the data is missing by percentage

# %%
df.isnull().sum()/148654*100
# Out:
# Id                    0.000000
# EmployeeName          0.000673
# JobTitle              0.000000
# BasePay               0.407658
# OvertimePay           0.000000
# OtherPay              0.001345
# Benefits             24.324270
# TotalPay              0.000000
# TotalPayBenefits      0.000000
# Year                  0.000000
# Notes               100.000000
# Agency                0.000000
# Status               74.357232
# dtype: float64

# %%
#Delete the columns with more than 24% missing values

# %%
#Drop a Cloumn or Delete a Column

# %%
df.drop(columns=["Notes","Benefits","Status"], inplace = True)

# %%
# Delete all Rows if it has null values

# %%
df.dropna(inplace =True)

# %%
# Count the column entry how many a same value presentd

# %%
df["EmployeeName"].value_counts()
# Out:
# Kevin Lee               13
# Richard Lee             11
# William Wong            11
# Steven Lee              11
# Stanley Lee              9
#                         ..
# ALYSSA AVILES            1
# John Carajan             1
# Carlo A De Luzuriaga     1
# Antonio  Gonzalez Jr     1
# Carl  Cranford           1
# Name: EmployeeName, Length: 110310, dtype: int64

# %%
df.head(2)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2   3  ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay   TotalPay  TotalPayBenefits  Year  \
# 0  167411.18         0.0  400184.25  567595.43         567595.43  2011
# 2  212739.13   106088.18    16452.6  335279.91         335279.91  2011
#
#           Agency
# 0  San Francisco
# 2  San Francisco

# %%
df.drop(columns=["EmployeeName","JobTitle","TotalPayBenefits","Year","Agency"], inplace = True)

# %%
df.head(2)
# Out:
#    Id    BasePay OvertimePay   OtherPay   TotalPay
# 0   1  167411.18         0.0  400184.25  567595.43
# 2   3  212739.13   106088.18    16452.6  335279.91

# %%
# We have to work on it

# %%
# Chnage in object into integer or float

# %%
# Print unique Values that presented in the Columns

# %%
df.BasePay.unique()
# Out:
# array([167411.18, 212739.13, 118602.0, ..., '6.04', '15.5',
#        'Not Provided'], dtype=object)

# %%
df.BasePay.replace("Not Provided",np.nan)
# Out:
# 0         167411.18
# 2         212739.13
# 5          118602.0
# 7         256576.96
# 8         176932.64
#             ...
# 148649            0
# 148650          NaN
# 148651          NaN
# 148652          NaN
# 148653            0
# Name: BasePay, Length: 148045, dtype: object

# %%
# Convert all Object/String into numeric

# %%
df.BasePay=pd.to_numeric(df.BasePay,errors='coerce')

# %%
df.BasePay.unique()
# Out:
# array([1.6741118e+05, 2.1273913e+05, 1.1860200e+05, ..., 6.0400000e+00,
#        1.5500000e+01,           nan])

# %%
#Same for other columns

# %%
df.OvertimePay.unique()
# Out:
# array([0.0, 106088.18, 8601.0, ..., '102.7', '56.77', 'Not Provided'],
#       dtype=object)

# %%
df.BasePay.replace("OvertimePay",np.nan)
# Out:
# 0         167411.18
# 2         212739.13
# 5         118602.00
# 7         256576.96
# 8         176932.64
#             ...
# 148649         0.00
# 148650          NaN
# 148651          NaN
# 148652          NaN
# 148653         0.00
# Name: BasePay, Length: 148045, dtype: float64

# %%
df.OvertimePay=pd.to_numeric(df.OvertimePay,errors='coerce')

# %%
df.OvertimePay.unique()
# Out:
# array([0.0000000e+00, 1.0608818e+05, 8.6010000e+03, ..., 1.0270000e+02,
#        5.6770000e+01,           nan])

# %%
df.OtherPay.unique()
df.OtherPay.replace("Not Provided",np.nan)
df.OtherPay=pd.to_numeric(df.OtherPay,errors='coerce')

# %%
df.OvertimePay.unique()
# Out:
# array([0.0000000e+00, 1.0608818e+05, 8.6010000e+03, ..., 1.0270000e+02,
#        5.6770000e+01,           nan])

# %%
df.TotalPay.unique()
# Out:
# array([ 5.6759543e+05,  3.3527991e+05,  3.1628574e+05, ...,
#         1.2890000e+01,  6.0000000e+00, -6.1813000e+02])

# %%
# Remove all rows that contains NAN

# %%
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148041 entries, 0 to 148653
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Id           148041 non-null  int64
#  1   BasePay      148041 non-null  float64
#  2   OvertimePay  148041 non-null  float64
#  3   OtherPay     148041 non-null  float64
#  4   TotalPay     148041 non-null  float64
# dtypes: float64(4), int64(1)
# memory usage: 6.8 MB

# %%
df.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148041.000000  148041.000000  148041.000000  148041.000000
# mean    74194.684560   66324.128437    5084.175932    3641.350465
# std     42947.333776   42764.147896   11453.507758    7975.308532
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37015.000000   33586.500000       0.000000       0.000000
# 50%     74025.000000   65006.930000       0.000000     817.080000
# 75%    111640.000000   94691.050000    4694.800000    4242.100000
# max    148654.000000  319275.010000  220909.480000  400184.250000
#
#             TotalPay
# count  148041.000000
# mean    75049.654834
# std     50383.463228
# min      -618.130000
# 25%     36955.540000
# 50%     71643.410000
# 75%    106025.120000
# max    567595.430000

# %%
df=df[df>0]

# %%
df
# Out:
#             Id    BasePay  OvertimePay   OtherPay   TotalPay
# 0            1  167411.18          NaN  400184.25  567595.43
# 2            3  212739.13    106088.18   16452.60  335279.91
# 5            6  118602.00      8601.00  189082.74  316285.74
# 7            8  256576.96          NaN   51322.50  307899.46
# 8            9  176932.64     86362.68   40132.23  303427.55
# ...        ...        ...          ...        ...        ...
# 148645  148646        NaN          NaN        NaN        NaN
# 148647  148648        NaN          NaN        NaN        NaN
# 148648  148649        NaN          NaN        NaN        NaN
# 148649  148650        NaN          NaN        NaN        NaN
# 148653  148654        NaN          NaN        NaN        NaN
#
# [148041 rows x 5 columns]

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#             Id    BasePay  OvertimePay   OtherPay   TotalPay
# 2            3  212739.13    106088.18   16452.60  335279.91
# 5            6  118602.00      8601.00  189082.74  316285.74
# 8            9  176932.64     86362.68   40132.23  303427.55
# 10          11  194999.39     71344.88   33149.90  299494.17
# 11          12   99722.00     87082.62  110804.30  297608.92
# ...        ...        ...          ...        ...        ...
# 147467  147468    1182.12       487.38      44.03    1713.53
# 147535  147536    1160.08       426.15      15.15    1601.38
# 147658  147659    1282.97        36.66      49.85    1369.48
# 147659  147660     426.44       273.24     431.56    1131.24
# 147689  147690     365.68       705.24      12.19    1083.11
#
# [64307 rows x 5 columns]

# %% [markdown]
# # NEW FILE

# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import time

# %%
df1=pd.read_csv("G:/cadd/Excel File/Sort_Order.csv")

# %%
#Add new column to the Data Frame

# %%
df1["Discount"]=df1["OvertimePay"]*10/100

# %%
df1.head(10)
# Out:
#          EmployeeName    BasePay  OvertimePay   OtherPay   TotalPay  \
# 0      NATHANIEL FORD  167411.18         0.00  400184.25  567595.43
# 1        GARY JIMENEZ  155966.02    245131.88        NaN  538909.28
# 2      ALBERT PARDINI  212739.13    106088.18   16452.60  335279.91
# 3                 NaN   77916.00     56120.71  198306.90  332343.61
# 4     PATRICK GARDNER  134401.60      9737.00        NaN  326373.19
# 5      DAVID SULLIVAN  118602.00      8601.00  189082.74  316285.74
# 6           ALSON LEE        NaN     89062.90  134426.14  315981.05
# 7       DAVID KUSHNER  256576.96         0.00   51322.50  307899.46
# 8      MICHAEL MORRIS  176932.64     86362.68   40132.23  303427.55
# 9  JOANNE HAYES-WHITE  285262.00         0.00   17115.73  302377.73
#
#    TotalPayBenefits   Discount
# 0         567595.43      0.000
# 1         538909.28  24513.188
# 2         335279.91  10608.818
# 3         332343.61   5612.071
# 4         326373.19    973.700
# ...

# %%
df1["BasePay"]=df1["BasePay"]//1

# %%
df1.head(10)
# Out:
#          EmployeeName   BasePay  OvertimePay   OtherPay   TotalPay  \
# 0      NATHANIEL FORD  167411.0         0.00  400184.25  567595.43
# 1        GARY JIMENEZ  155966.0    245131.88        NaN  538909.28
# 2      ALBERT PARDINI  212739.0    106088.18   16452.60  335279.91
# 3                 NaN   77916.0     56120.71  198306.90  332343.61
# 4     PATRICK GARDNER  134401.0      9737.00        NaN  326373.19
# 5      DAVID SULLIVAN  118602.0      8601.00  189082.74  316285.74
# 6           ALSON LEE       NaN     89062.90  134426.14  315981.05
# 7       DAVID KUSHNER  256576.0         0.00   51322.50  307899.46
# 8      MICHAEL MORRIS  176932.0     86362.68   40132.23  303427.55
# 9  JOANNE HAYES-WHITE  285262.0         0.00   17115.73  302377.73
#
#    TotalPayBenefits   Discount
# 0         567595.43      0.000
# 1         538909.28  24513.188
# 2         335279.91  10608.818
# 3         332343.61   5612.071
# 4         326373.19    973.700
# 5         316285.74    860.100
# ...

# %%
 df1.shape
# Out:
# (28, 7)

# %%
df1.fillna(value=0,inplace=True)


"""is used to fill missing or NaN (Not a Number) values in a pandas DataFrame df1 with a specified value, 
which in this case is 0. Let's break down the components of this code:"""
# Out:
# "is used to fill missing or NaN (Not a Number) values in a pandas DataFrame df1 with a specified value, \nwhich in this case is 0. Let's break down the components of this code:"

# %%
df1.head(10)
# Out:
#          EmployeeName   BasePay  OvertimePay   OtherPay   TotalPay  \
# 0      NATHANIEL FORD  167411.0         0.00  400184.25  567595.43
# 1        GARY JIMENEZ  155966.0    245131.88       0.00  538909.28
# 2      ALBERT PARDINI  212739.0    106088.18   16452.60  335279.91
# 3                   0   77916.0     56120.71  198306.90  332343.61
# 4     PATRICK GARDNER  134401.0      9737.00       0.00  326373.19
# 5      DAVID SULLIVAN  118602.0      8601.00  189082.74  316285.74
# 6           ALSON LEE       0.0     89062.90  134426.14  315981.05
# 7       DAVID KUSHNER  256576.0         0.00   51322.50  307899.46
# 8      MICHAEL MORRIS  176932.0     86362.68   40132.23  303427.55
# 9  JOANNE HAYES-WHITE  285262.0         0.00   17115.73  302377.73
#
#    TotalPayBenefits   Discount
# 0         567595.43      0.000
# 1         538909.28  24513.188
# 2         335279.91  10608.818
# 3         332343.61   5612.071
# 4         326373.19    973.700
# 5         316285.74    860.100
# ...

# %%
mean=np.mean(df1["BasePay"]) #To Find the average 1

# %%
mean
# Out:
# 183481.5357142857

# %%
ave=df1["BasePay"].mean()#To Find the average 2

# %%
ave
# Out:
# 183481.5357142857

# %%
max=np.max(df1["BasePay"])

# %%
max
# Out:
# 294580.0

# %%
max=df1["BasePay"].max()

# %%
max
# Out:
# 294580.0

# %%
min=np.min(df1["BasePay"])

# %%
min
# Out:
# 0.0

# %%
min=df1["BasePay"].min()

# %%
min
# Out:
# 0.0

# %%
#Change the column name

# %%
df1.rename(columns={"EmployeeName":"Employee"},inplace=True)

# %%
df1.head(10)
# Out:
#              Employee   BasePay  OvertimePay   OtherPay   TotalPay  \
# 0      NATHANIEL FORD  167411.0         0.00  400184.25  567595.43
# 1        GARY JIMENEZ  155966.0    245131.88       0.00  538909.28
# 2      ALBERT PARDINI  212739.0    106088.18   16452.60  335279.91
# 3                   0   77916.0     56120.71  198306.90  332343.61
# 4     PATRICK GARDNER  134401.0      9737.00       0.00  326373.19
# 5      DAVID SULLIVAN  118602.0      8601.00  189082.74  316285.74
# 6           ALSON LEE       0.0     89062.90  134426.14  315981.05
# 7       DAVID KUSHNER  256576.0         0.00   51322.50  307899.46
# 8      MICHAEL MORRIS  176932.0     86362.68   40132.23  303427.55
# 9  JOANNE HAYES-WHITE  285262.0         0.00   17115.73  302377.73
#
#    TotalPayBenefits   Discount
# 0         567595.43      0.000
# 1         538909.28  24513.188
# 2         335279.91  10608.818
# 3         332343.61   5612.071
# 4         326373.19    973.700
# 5         316285.74    860.100
# ...

# %%
#Remove outliers

# %%
#df1=df1[   (df1["BasePay"]>=lower_bound) & (df1["BasePay"]<=upper_bound)   ]

# %%
#Add a new column to a data frame

# %%
#for i in df1["OtherPay"]:

# %%
df1["Ship_Charge"]=[i*2/100 for i in df1["OtherPay"]]

# %%
df1.head(10)
# Out:
#              Employee   BasePay  OvertimePay   OtherPay   TotalPay  \
# 0      NATHANIEL FORD  167411.0         0.00  400184.25  567595.43
# 1        GARY JIMENEZ  155966.0    245131.88       0.00  538909.28
# 2      ALBERT PARDINI  212739.0    106088.18   16452.60  335279.91
# 3                   0   77916.0     56120.71  198306.90  332343.61
# 4     PATRICK GARDNER  134401.0      9737.00       0.00  326373.19
# 5      DAVID SULLIVAN  118602.0      8601.00  189082.74  316285.74
# 6           ALSON LEE       0.0     89062.90  134426.14  315981.05
# 7       DAVID KUSHNER  256576.0         0.00   51322.50  307899.46
# 8      MICHAEL MORRIS  176932.0     86362.68   40132.23  303427.55
# 9  JOANNE HAYES-WHITE  285262.0         0.00   17115.73  302377.73
#
#    TotalPayBenefits   Discount  Ship_Charge
# 0         567595.43      0.000    8003.6850
# 1         538909.28  24513.188       0.0000
# 2         335279.91  10608.818     329.0520
# 3         332343.61   5612.071    3966.1380
# ...

# %%
#Make correction to values in a column

# %%
df1["Employee"].replace({"NATHANIEL FORD":"Farid","ALSON LEE":"Zishan","MICHAEL MORRIS":"Rizwan"},inplace=True)

# %%
df1.head(10)
# Out:
#              Employee   BasePay  OvertimePay   OtherPay   TotalPay  \
# 0               Farid  167411.0         0.00  400184.25  567595.43
# 1        GARY JIMENEZ  155966.0    245131.88       0.00  538909.28
# 2      ALBERT PARDINI  212739.0    106088.18   16452.60  335279.91
# 3                   0   77916.0     56120.71  198306.90  332343.61
# 4     PATRICK GARDNER  134401.0      9737.00       0.00  326373.19
# 5      DAVID SULLIVAN  118602.0      8601.00  189082.74  316285.74
# 6              Zishan       0.0     89062.90  134426.14  315981.05
# 7       DAVID KUSHNER  256576.0         0.00   51322.50  307899.46
# 8              Rizwan  176932.0     86362.68   40132.23  303427.55
# 9  JOANNE HAYES-WHITE  285262.0         0.00   17115.73  302377.73
#
#    TotalPayBenefits   Discount  Ship_Charge
# 0         567595.43      0.000    8003.6850
# 1         538909.28  24513.188       0.0000
# 2         335279.91  10608.818     329.0520
# 3         332343.61   5612.071    3966.1380
# ...

# %% [markdown]
# # Aggregation function fucntions on Columns

# %%
#Sum of columns values

# %%
x=df1["BasePay"].sum()

# %%
x
# Out:
# 5137483.0

# %%
#Average of a column

# %%
Ave=df1["BasePay"].mean()

# %%
Ave
# Out:
# 183481.5357142857

# %%
#Min value of a column

# %%
Min=df1["BasePay"].min()

# %%
Min
# Out:
# 0.0

# %%
#Max value of a column

# %%
Max=df1["BasePay"].max()

# %%
Max
# Out:
# 294580.0

# %%
#group by  column a calculate the SUM

# %%
Grp=df1.groupby("Employee").sum()

# %%
Grp
# Out:
#                      BasePay  OvertimePay   OtherPay   TotalPay  \
# Employee
# 0                    77916.0     56120.71  198306.90  332343.61
# ALBERT PARDINI      212739.0    106088.18   16452.60  335279.91
# AMY HART            268604.0         0.00   16115.86  284720.43
# ARTHUR KENNEY       194999.0     71344.88   33149.90  299494.17
# DAVID FRANKLIN      174872.0     74050.30   37424.11  286347.05
# DAVID KUSHNER       256576.0         0.00   51322.50  307899.46
# DAVID SULLIVAN      118602.0      8601.00  189082.74  316285.74
# EDWARD HARRINGTON   294580.0         0.00       0.00  294580.02
# ELLEN MOFFATT       257510.0       880.16   16159.50  274550.25
# Farid               167411.0         0.00  400184.25  567595.43
# GARY JIMENEZ        155966.0    245131.88       0.00  538909.28
# GEORGE GARCIA       140546.0     93200.58   39955.25  273702.71
# GREGORY SUHR        256470.0         0.00   11522.18  267992.59
# ...

# %% [markdown]
# # Basic operation in ROWS

# %%
df1.head(3)
# Out:
#          Employee   BasePay  OvertimePay   OtherPay   TotalPay  \
# 0           Farid  167411.0         0.00  400184.25  567595.43
# 1    GARY JIMENEZ  155966.0    245131.88       0.00  538909.28
# 2  ALBERT PARDINI  212739.0    106088.18   16452.60  335279.91
#
#    TotalPayBenefits   Discount  Ship_Charge
# 0         567595.43      0.000     8003.685
# 1         538909.28  24513.188        0.000
# 2         335279.91  10608.818      329.052

# %%
#Select a ROW by in index

# %%
row=df1.loc[2]

# %%
row
# Out:
# Employee            ALBERT PARDINI
# BasePay                   212739.0
# OvertimePay              106088.18
# OtherPay                   16452.6
# TotalPay                 335279.91
# TotalPayBenefits         335279.91
# Discount                 10608.818
# Ship_Charge                329.052
# Name: 2, dtype: object

# %%
#Filtering the rows based on Conditions

# %%
fl=df1[df1["OtherPay"]>=20000]

# %%
fl
# Out:
#             Employee   BasePay  OvertimePay   OtherPay   TotalPay  \
# 0              Farid  167411.0         0.00  400184.25  567595.43
# 3                  0   77916.0     56120.71  198306.90  332343.61
# 5     DAVID SULLIVAN  118602.0      8601.00  189082.74  316285.74
# 6             Zishan       0.0     89062.90  134426.14  315981.05
# 7      DAVID KUSHNER  256576.0         0.00   51322.50  307899.46
# 8             Rizwan  176932.0     86362.68   40132.23  303427.55
# 10     ARTHUR KENNEY  194999.0     71344.88   33149.90  299494.17
# 11  PATRICIA JACKSON   99722.0     87082.62  110804.30  297608.92
# 13       JOHN MARTIN  271329.0         0.00   21342.59  292671.62
# 14    DAVID FRANKLIN  174872.0     74050.30   37424.11  286347.05
# 18        MARTY ROSS  168692.0     69626.12   38115.47  276434.22
# 22     GEORGE GARCIA  140546.0     93200.58   39955.25  273702.71
# 23     VICTOR WYRSCH  168692.0     77896.14   24083.86  270672.63
# ...

# %%
#Adding a new ROW to the DataFrame

# %%
New_row={"Employee":"Ansari","BasePay":3211,"OvertimePay":3244,"OtherPay":52524,"TotalPay":5252,"TotalPayBenefits":74634,"Discount":73638,"Ship_Charge":8463}

# %%
df1=df1.append(New_row,ignore_index=True)

# %%
df1.head(2)
# Out:
#        Employee   BasePay  OvertimePay   OtherPay   TotalPay  \
# 0         Farid  167411.0         0.00  400184.25  567595.43
# 1  GARY JIMENEZ  155966.0    245131.88       0.00  538909.28
#
#    TotalPayBenefits   Discount  Ship_Charge
# 0         567595.43      0.000     8003.685
# 1         538909.28  24513.188        0.000

# %%
df1.tail(2)
# Out:
#           Employee   BasePay  OvertimePay  OtherPay   TotalPay  \
# 27  RAYMOND GUZMAN  168692.0     80706.88  16063.99  265463.46
# 28          Ansari    3211.0      3244.00  52524.00    5252.00
#
#     TotalPayBenefits   Discount  Ship_Charge
# 27         265463.46   8070.688     321.2798
# 28          74634.00  73638.000    8463.0000

# %% [markdown]
# # Aggregation function on ROWS

# %%
#SUM of value in a row

# %%
df1["SUM"]=df1.sum(axis=1)
df_sorted = df1.sort_values('SUM', ascending=True)

# %%
df1.head(5)
# Out:
#           Employee   BasePay  OvertimePay   OtherPay   TotalPay  \
# 0            Farid  167411.0         0.00  400184.25  567595.43
# 1     GARY JIMENEZ  155966.0    245131.88       0.00  538909.28
# 2   ALBERT PARDINI  212739.0    106088.18   16452.60  335279.91
# 3                0   77916.0     56120.71  198306.90  332343.61
# 4  PATRICK GARDNER  134401.0      9737.00       0.00  326373.19
#
#    TotalPayBenefits   Discount  Ship_Charge        Max          SUM
# 0         567595.43      0.000     8003.685  567595.43  5124365.880
# 1         538909.28  24513.188        0.000  538909.28  4623587.096
# 2         335279.91  10608.818      329.052  335279.91  3039394.670
# 3         332343.61   5612.071     3966.138  332343.61  3010248.908
# 4         326373.19    973.700        0.000  326373.19  2574835.730
