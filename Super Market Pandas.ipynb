# %%
import pandas as pd

# %%
df=pd.read_excel("A:\SuperStoreUS-2015.xlsx")

# %%
df.head(5)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
#Print all the column

# %%
df.columns  #Print all the column
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'City', 'Postal Code', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
#Print the specific column

# %%
df['Order Priority']  #Print the specific column
# Out:
# 0                High
# 1       Not Specified
# 2            Critical
# 3              Medium
# 4              Medium
#             ...
# 1947             High
# 1948             High
# 1949    Not Specified
# 1950           Medium
# 1951             High
# Name: Order Priority, Length: 1952, dtype: object

# %%
# df.dtypes #It will show the data type of all columns

# %%
df.dtypes=='float64' #True if the data type is 'float64'
# Out:
# Row ID                  False
# Order Priority          False
# Discount                 True
# Unit Price               True
# Shipping Cost            True
# Customer ID             False
# Customer Name           False
# Ship Mode               False
# Customer Segment        False
# Product Category        False
# Product Sub-Category    False
# Product Container       False
# Product Name            False
# Product Base Margin      True
# Country                 False
# Region                  False
# State or Province       False
# City                    False
# Postal Code             False
# Order Date              False
# Ship Date               False
# Profit                   True
# Quantity ordered new    False
# Sales                    True
# Order ID                False
# dtype: bool

# %%
for column in df.columns:
    if df[column].dtype == 'float64':
        print(column)

#It will show only those columns whose data type is 'float64'
# Out:
# Discount
# Unit Price
# Shipping Cost
# Product Base Margin
# Profit
# Sales

# %%
df.dtypes[df.dtypes=='float64']  #It will show float64 data type column only
# Out:
# Discount               float64
# Unit Price             float64
# Shipping Cost          float64
# Product Base Margin    float64
# Profit                 float64
# Sales                  float64
# dtype: object

# %%
df.dtypes[df.dtypes=='int64']  #It will show int64 data type column only
# Out:
# Row ID                  int64
# Customer ID             int64
# Postal Code             int64
# Quantity ordered new    int64
# Order ID                int64
# dtype: object

# %%
df.dtypes[df.dtypes=='object']  #It will show object data type column only
# Out:
# Order Priority          object
# Customer Name           object
# Ship Mode               object
# Customer Segment        object
# Product Category        object
# Product Sub-Category    object
# Product Container       object
# Product Name            object
# Country                 object
# Region                  object
# State or Province       object
# City                    object
# dtype: object

# %%
df.dtypes[df.dtypes=='datetime64[ns]']  #It will show datetime64[ns] data type column only
# Out:
# Order Date    datetime64[ns]
# Ship Date     datetime64[ns]
# dtype: object

# %%
x=df.dtypes[df.dtypes=='object'].index  #It will show object data type column only in List

# %%
#It will print the list of object column

# %%
x
# Out:
# Index(['Order Priority', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Country', 'Region', 'State or Province', 'City'],
#       dtype='object')

# %%
for i in x:  # It will extract only city column
    if i=='City':
        print(i)
# Out:
# City

# %%
df[i]  # It will print all the cities name
# Out:
# 0         Anacortes
# 1       San Gabriel
# 2           Roselle
# 3        Prior Lake
# 4        Prior Lake
#            ...
# 1947       Danville
# 1948       Danville
# 1949    Des Plaines
# 1950       Fairmont
# 1951       Cheyenne
# Name: City, Length: 1952, dtype: object

# %%
df.dtypes[df.dtypes=='object']
# Out:
# Order Priority          object
# Customer Name           object
# Ship Mode               object
# Customer Segment        object
# Product Category        object
# Product Sub-Category    object
# Product Container       object
# Product Name            object
# Country                 object
# Region                  object
# State or Province       object
# City                    object
# dtype: object

# %%
# Pass this above object data into datframe

# %%
# df[df.dtypes[df.dtypes=='object']]  #KeyError: "None of [Index([ob

# %%
df[df.dtypes[df.dtypes=='object'].index] # It will print the dataFrame where dtypes=='object
# Out:
#      Order Priority      Customer Name       Ship Mode Customer Segment  \
# 0              High      Bonnie Potter     Express Air        Corporate
# 1     Not Specified     Ronnie Proctor  Delivery Truck      Home Office
# 2          Critical      Marcus Dunlap     Regular Air      Home Office
# 3            Medium  Gwendolyn F Tyson     Regular Air   Small Business
# 4            Medium  Gwendolyn F Tyson     Regular Air   Small Business
# ...             ...                ...             ...              ...
# 1947           High        Andrea Shaw     Regular Air   Small Business
# 1948           High        Andrea Shaw     Regular Air   Small Business
# 1949  Not Specified        Marvin Reid     Regular Air   Small Business
# 1950         Medium      Florence Gold     Express Air   Small Business
# 1951           High      Tammy Buckley     Express Air         Consumer
#
#      Product Category          Product Sub-Category Product Container  \
# ...

# %%
# df.columns  #Print all the column
# df['Order Priority']  #Print the specific column
# df.dtypes=='float64' #True if the data type is 'float64'
# df.dtypes[df.dtypes=='float64']  #It will show float64 data type column only
# x=df.dtypes[df.dtypes=='object'].index  #It will show object data type column only in List
# df[df.dtypes[df.dtypes=='object'].index] # It will print the dataFrame where dtypes=='object
# df[df.dtypes[df.dtypes=='object'].index].describe() It will Describe the dala

# %%
df[df.dtypes[df.dtypes=='object'].index].describe()  #4:21 AM
# Out:
#        Order Priority Customer Name    Ship Mode Customer Segment  \
# count            1952          1952         1952             1952
# unique              6          1130            3                4
# top               Low    Jenny Gold  Regular Air        Corporate
# freq              398             9         1437              684
#
#        Product Category Product Sub-Category Product Container  \
# count              1952                 1952              1952
# unique                3                   17                 7
# top     Office Supplies                Paper         Small Box
# freq               1071                  284               991
#
#                            Product Name        Country   Region  \
# count                              1952           1952     1952
# unique                              913              1        4
# top     Bevis 36 x 72 Conference Tables  United States  Central
# ...

# %%
df['Customer Name']
# Out:
# 0           Bonnie Potter
# 1          Ronnie Proctor
# 2           Marcus Dunlap
# 3       Gwendolyn F Tyson
# 4       Gwendolyn F Tyson
#               ...
# 1947          Andrea Shaw
# 1948          Andrea Shaw
# 1949          Marvin Reid
# 1950        Florence Gold
# 1951        Tammy Buckley
# Name: Customer Name, Length: 1952, dtype: object

# %%
df['Customer Name'][1:4]
# Out:
# 1       Ronnie Proctor
# 2        Marcus Dunlap
# 3    Gwendolyn F Tyson
# Name: Customer Name, dtype: object

# %%
df['Customer Name'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1947    False
# 1948    False
# 1949    False
# 1950    False
# 1951    False
# Name: Customer Name, Length: 1952, dtype: bool

# %%
# Name 5 custumers who belog to New York City

# %%
df[df["City"] == "New York City"]["Customer Name"][1:6]
# Out:
# 14    Tony Wilkins Winters
# 15    Tony Wilkins Winters
# 36              Scott Bunn
# 37              Scott Bunn
# 38              Scott Bunn
# Name: Customer Name, dtype: object

# %% [markdown]
# # Working on float Data Type

# %%
# Extrac the column whose data type is 'float64'

# %%
df.dtypes[df.dtypes=='float64']
# Out:
# Discount               float64
# Unit Price             float64
# Shipping Cost          float64
# Product Base Margin    float64
# Profit                 float64
# Sales                  float64
# dtype: object

# %%
df[df.dtypes[df.dtypes=='float64'].index]  #4:48:00AM
# Out:
#       Discount  Unit Price  Shipping Cost  Product Base Margin     Profit  \
# 0         0.01        2.84           0.93                 0.54     4.5600
# 1         0.02      500.98          26.00                 0.60  4390.3665
# 2         0.06        9.48           7.29                 0.45   -53.8096
# 3         0.09       78.69          19.99                 0.43   803.4705
# 4         0.08        3.28           2.31                 0.56   -24.0300
# ...        ...         ...            ...                  ...        ...
# 1947      0.01       10.90           7.46                 0.59  -116.7600
# 1948      0.10        7.99           5.03                 0.60  -160.9520
# 1949      0.08       11.97           5.81                 0.60   -41.8700
# 1950      0.10        9.38           4.93                 0.57   -24.7104
# 1951      0.10      105.98          13.99                 0.65   349.4850
#
#         Sales
# 0       13.01
# 1     6362.85
# 2      211.15
# 3     1164.45
# ...

# %%
df['Discount'][1:5]  # Show starting 4 Discount
# Out:
# 1    0.02
# 2    0.06
# 3    0.09
# 4    0.08
# Name: Discount, dtype: float64

# %%
df['Discount'][1:20:2] # Alternative or Jump by 1
# Out:
# 1     0.02
# 3     0.09
# 5     0.05
# 7     0.00
# 9     0.04
# 11    0.05
# 13    0.05
# 15    0.07
# 17    0.02
# 19    0.08
# Name: Discount, dtype: float64

# %%
# Series act like List

# %%
df[df.dtypes[df.dtypes=='float64'].index]
# Out:
#       Discount  Unit Price  Shipping Cost  Product Base Margin     Profit  \
# 0         0.01        2.84           0.93                 0.54     4.5600
# 1         0.02      500.98          26.00                 0.60  4390.3665
# 2         0.06        9.48           7.29                 0.45   -53.8096
# 3         0.09       78.69          19.99                 0.43   803.4705
# 4         0.08        3.28           2.31                 0.56   -24.0300
# ...        ...         ...            ...                  ...        ...
# 1947      0.01       10.90           7.46                 0.59  -116.7600
# 1948      0.10        7.99           5.03                 0.60  -160.9520
# 1949      0.08       11.97           5.81                 0.60   -41.8700
# 1950      0.10        9.38           4.93                 0.57   -24.7104
# 1951      0.10      105.98          13.99                 0.65   349.4850
#
#         Sales
# 0       13.01
# 1     6362.85
# 2      211.15
# 3     1164.45
# ...

# %%
# FInd out the person who has Max profit

# %%
df["Customer Name"]==max(df['Profit']) # where there is max there is True
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1947    False
# 1948    False
# 1949    False
# 1950    False
# 1951    False
# Name: Customer Name, Length: 1952, dtype: bool

# %%
df[df["Customer Name"]==max(df['Profit'])]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order Priority, Discount, Unit Price, Shipping Cost, Customer ID, Customer Name, Ship Mode, Customer Segment, Product Category, Product Sub-Category, Product Container, Product Name, Product Base Margin, Country, Region, State or Province, City, Postal Code, Order Date, Ship Date, Profit, Quantity ordered new, Sales, Order ID]
# Index: []
#
# [0 rows x 25 columns]

# %%
# Find out the data from 'New York City'

# %%
df['City']=='New York City'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1947    False
# 1948    False
# 1949    False
# 1950    False
# 1951    False
# Name: City, Length: 1952, dtype: bool

# %%
df[df['City']=='New York City']
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 13      5890           High      0.05       26.48           6.93           21
# 14      6062  Not Specified      0.08        5.00           3.39           21
# 15      6063  Not Specified      0.07       12.99           9.44           21
# 36      5272            Low      0.00      291.73          48.80           68
# 37      5273            Low      0.07      100.98          45.00           68
# 38      5274            Low      0.05      155.06           7.07           68
# 39      7786           High      0.09      122.99          70.20           68
# 256     1147         Medium      0.08        2.94           0.96          491
# 257     1450       Critical      0.01        4.98           6.07          491
# 258      914       Critical      0.02     1360.14          14.70          491
# 259     6046  Not Specified      0.02        9.06           9.86          491
# ...

# %%
#There are 47 Records from 'New York City'

# %%
len(df[df['City']=='New York City'])
# Out:
# 47

# %%
# Find out the records where the shipment is more then 2

# %%
df["Shipping Cost"]>10
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 1947    False
# 1948    False
# 1949    False
# 1950    False
# 1951     True
# Name: Shipping Cost, Length: 1952, dtype: bool

# %%
df[df["Shipping Cost"]>10]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1      20228  Not Specified      0.02      500.98          26.00            5
# 3      24844         Medium      0.09       78.69          19.99           14
# 16     20631           High      0.06       55.48          14.30           24
# 25     25933           High      0.00       99.99          19.99           43
# 36      5272            Low      0.00      291.73          48.80           68
# ...      ...            ...       ...         ...            ...          ...
# 1935   23182       Critical      0.09      276.20          24.49         3380
# 1936   23183       Critical      0.03       63.94          14.48         3380
# 1943   19464  Not Specified      0.03       95.99          35.00         3388
# 1946   20624            Low      0.00     1270.99          19.99         3397
# 1951   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
#fond out the max Shipment

# %%
max(df["Shipping Cost"])
# Out:
# 164.73

# %%
# In which City the Shipment is very High

# %%
df[df["Shipping Cost"]>100]["City"]
# Out:
# 717      Cedar Park
# 1049       Appleton
# 1075        Bozeman
# 1127        Liberal
# 1224     Burnsville
# 1440    Los Angeles
# 1444      Whitehall
# Name: City, dtype: object

# %%
# 6:44:00AM Sunday

# %% [markdown]
# # Date Operation

# %%
df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
df.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Country                         object
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# ...

# %%
# Here the date column data type is datetime64[ns]
# So dont need to convert its type

# %%
#Convert any data type to Date format

# %%
#  pd.to_datetime(df['Column_name'])

# %%
df['Order Date']
# Out:
# 0      2015-01-07
# 1      2015-06-13
# 2      2015-02-15
# 3      2015-05-12
# 4      2015-05-12
#           ...
# 1947   2015-03-11
# 1948   2015-03-11
# 1949   2015-03-29
# 1950   2015-04-04
# 1951   2015-02-08
# Name: Order Date, Length: 1952, dtype: datetime64[ns]

# %%
# Extract the year and create a new column

# %%
df['Converted_Order_year']=df['Order Date'].dt.year

# %%
df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
df['Converted_Order_year']
# Out:
# 0       2015
# 1       2015
# 2       2015
# 3       2015
# 4       2015
#         ...
# 1947    2015
# 1948    2015
# 1949    2015
# 1950    2015
# 1951    2015
# Name: Converted_Order_year, Length: 1952, dtype: int64

# %%
# Extract the month and create a new Column

# %%
df['Converted_Order_month']=df['Order Date'].dt.month

# %%
df['Converted_Order_month']
# Out:
# 0       1
# 1       6
# 2       2
# 3       5
# 4       5
#        ..
# 1947    3
# 1948    3
# 1949    3
# 1950    4
# 1951    2
# Name: Converted_Order_month, Length: 1952, dtype: int64

# %%
# Extract the week and create a new Column

# %%
df['Converted_Order_Week']=df['Order Date'].dt.week
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_3964\1772113963.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['Converted_Order_Week']=df['Order Date'].dt.week

# %%
df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
# Try to show the data that in 2014

# %%
df[df['Converted_Order_year']==2015]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 1      20228  Not Specified      0.02      500.98          26.00            5
# 2      21776       Critical      0.06        9.48           7.29           11
# 3      24844         Medium      0.09       78.69          19.99           14
# 4      24846         Medium      0.08        3.28           2.31           14
# ...      ...            ...       ...         ...            ...          ...
# 1947   19842           High      0.01       10.90           7.46         3397
# 1948   19843           High      0.10        7.99           5.03         3397
# 1949   26208  Not Specified      0.08       11.97           5.81         3399
# 1950   24911         Medium      0.10        9.38           4.93         3400
# 1951   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
# Find out the month in which it had done max sale and sum the sale

# %%
max(df['Sales'])
# Out:
# 45737.33

# %%
# FInd the cost to the company

# %%
Discount  Shipping Cost

# %%
df['Company_cost']=df['Discount']+df['Shipping Cost']

# %%
df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
# Find out which particular ID or product having the highest cost to the company

# %%
max(df['Company_cost'])
# Out:
# 164.73

# %%
df[df['Company_cost']==max(df['Company_cost'])]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1049   23260       Critical       0.0      300.98         164.73         1894
#
#              Customer Name       Ship Mode Customer Segment Product Category  \
# 1049  Maureen Herbert Hood  Delivery Truck      Home Office        Furniture
#
#       ... Order Date  Ship Date     Profit  Quantity ordered new    Sales  \
# 1049  ... 2015-02-24 2015-02-25  2653.2915                    12  3845.35
#
#      Order ID Converted_Order_year Converted_Order_month  \
# 1049    91261                 2015                     2
#
#       Converted_Order_Week Company_cost
# 1049                     9       164.73
#
# [1 rows x 29 columns]

# %%
# 8:35:00 AM Sunday

# %%
df.drop('Company_cost', axis=1) # Delete the Column
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 1      20228  Not Specified      0.02      500.98          26.00            5
# 2      21776       Critical      0.06        9.48           7.29           11
# 3      24844         Medium      0.09       78.69          19.99           14
# 4      24846         Medium      0.08        3.28           2.31           14
# ...      ...            ...       ...         ...            ...          ...
# 1947   19842           High      0.01       10.90           7.46         3397
# 1948   19843           High      0.10        7.99           5.03         3397
# 1949   26208  Not Specified      0.08       11.97           5.81         3399
# 1950   24911         Medium      0.10        9.38           4.93         3400
# 1951   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
#Try to show Coulumm 1 and 2

# %%
df[['Order Priority','Discount']]
# Out:
#      Order Priority  Discount
# 0              High      0.01
# 1     Not Specified      0.02
# 2          Critical      0.06
# 3            Medium      0.09
# 4            Medium      0.08
# ...             ...       ...
# 1947           High      0.01
# 1948           High      0.10
# 1949  Not Specified      0.08
# 1950         Medium      0.10
# 1951           High      0.10
#
# [1952 rows x 2 columns]

# %%
#Try to show Row1 and Row2

# %%
df.loc[[1,2]] # Just by indexing numbers
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
#
#     Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 1  Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2   Marcus Dunlap     Regular Air      Home Office        Furniture  ...
#
#   Order Date  Ship Date     Profit  Quantity ordered new    Sales Order ID  \
# 1 2015-06-13 2015-06-15  4390.3665                    12  6362.85    90193
# 2 2015-02-15 2015-02-17   -53.8096                    22   211.15    90192
#
#   Converted_Order_year Converted_Order_month  Converted_Order_Week  \
# 1                 2015                     6                    24
# 2                 2015                     2                     7
#
#   Company_cost
# 1        26.02
# 2         7.35
#
# [2 rows x 29 columns]

# %%
df.loc[[1,2,3]]  # Just by indexing numbers
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
#
#   Order Date  Ship Date     Profit  Quantity ordered new    Sales Order ID  \
# 1 2015-06-13 2015-06-15  4390.3665                    12  6362.85    90193
# 2 2015-02-15 2015-02-17   -53.8096                    22   211.15    90192
# 3 2015-05-12 2015-05-14   803.4705                    16  1164.45    86838
#
# ...

# %%
df.loc[1:5] # Indexing range
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
# 5   24847         Medium      0.05        3.28           4.20           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
# 5  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
df.loc[[2,3,1,2,4]]
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
df.loc[[2,3,3,3]]
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 3   24844         Medium      0.09       78.69          19.99           14
# 3   24844         Medium      0.09       78.69          19.99           14
#
#        Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 2      Marcus Dunlap  Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson  Regular Air   Small Business        Furniture  ...
# 3  Gwendolyn F Tyson  Regular Air   Small Business        Furniture  ...
# 3  Gwendolyn F Tyson  Regular Air   Small Business        Furniture  ...
#
#   Order Date  Ship Date    Profit  Quantity ordered new    Sales Order ID  \
# 2 2015-02-15 2015-02-17  -53.8096                    22   211.15    90192
# ...

# %%
# Show Clumns and Rows at a time by indexing

# %%
df.iloc[1:3,2:4]
# Out:
#    Discount  Unit Price
# 1      0.02      500.98
# 2      0.06        9.48

# %%
df.loc[0:4,['Row ID','Order Priority','Discount']]
# Out:
#    Row ID Order Priority  Discount
# 0   20847           High      0.01
# 1   20228  Not Specified      0.02
# 2   21776       Critical      0.06
# 3   24844         Medium      0.09
# 4   24846         Medium      0.08

# %%
# Filter out the data where the numbers are greater than 100

# %%
df.dtypes
# Out:
# Row ID                            int64
# Order Priority                   object
# Discount                        float64
# Unit Price                      float64
# Shipping Cost                   float64
# Customer ID                       int64
# Customer Name                    object
# Ship Mode                        object
# Customer Segment                 object
# Product Category                 object
# Product Sub-Category             object
# Product Container                object
# Product Name                     object
# Product Base Margin             float64
# Country                          object
# Region                           object
# State or Province                object
# City                             object
# Postal Code                       int64
# Order Date               datetime64[ns]
# Ship Date                datetime64[ns]
# Profit                          float64
# Quantity ordered new              int64
# ...

# %%
# Extract only the integer type data

# %%
df.dtypes[(df.dtypes=='int64')|(df.dtypes=='float64')]
# Out:
# Row ID                     int64
# Discount                 float64
# Unit Price               float64
# Shipping Cost            float64
# Customer ID                int64
# Product Base Margin      float64
# Postal Code                int64
# Profit                   float64
# Quantity ordered new       int64
# Sales                    float64
# Order ID                   int64
# Converted_Order_year       int64
# Converted_Order_month      int64
# Converted_Order_Week       int64
# Company_cost             float64
# dtype: object

# %%
# Find out the Datarame only for Integer

# %%
df2=df[df.dtypes[(df.dtypes=='int64')|(df.dtypes=='float64')].index]

# %%
df2
# Out:
#       Row ID  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847      0.01        2.84           0.93            3
# 1      20228      0.02      500.98          26.00            5
# 2      21776      0.06        9.48           7.29           11
# 3      24844      0.09       78.69          19.99           14
# 4      24846      0.08        3.28           2.31           14
# ...      ...       ...         ...            ...          ...
# 1947   19842      0.01       10.90           7.46         3397
# 1948   19843      0.10        7.99           5.03         3397
# 1949   26208      0.08       11.97           5.81         3399
# 1950   24911      0.10        9.38           4.93         3400
# 1951   25914      0.10      105.98          13.99         3403
#
#       Product Base Margin  Postal Code     Profit  Quantity ordered new  \
# 0                    0.54        98221     4.5600                     4
# ...

# %%
df3
# Out:
#        Row ID  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     20847.0       NaN         NaN            NaN          NaN
# 1     20228.0       NaN      500.98            NaN          NaN
# 2     21776.0       NaN         NaN            NaN          NaN
# 3     24844.0       NaN         NaN            NaN          NaN
# 4     24846.0       NaN         NaN            NaN          NaN
# ...       ...       ...         ...            ...          ...
# 1947  19842.0       NaN         NaN            NaN       3397.0
# 1948  19843.0       NaN         NaN            NaN       3397.0
# 1949  26208.0       NaN         NaN            NaN       3399.0
# 1950  24911.0       NaN         NaN            NaN       3400.0
# 1951  25914.0       NaN      105.98            NaN       3403.0
#
#       Product Base Margin  Postal Code     Profit  Quantity ordered new  \
# 0                     NaN        98221        NaN                   NaN
# ...

# %%
df3=df2[df2>10]

# %%
#where the value is less then 10, showing NaN

# %%
#Drop the Column and Row where the Value is null

# %%
df3.dropna()
# Out:
# Empty DataFrame
# Columns: [Row ID, Discount, Unit Price, Shipping Cost, Customer ID, Product Base Margin, Postal Code, Profit, Quantity ordered new, Sales, Order ID, Converted_Order_year, Converted_Order_month, Converted_Order_Week, Company_cost]
# Index: []
